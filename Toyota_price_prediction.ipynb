# %%
import pandas as pd

# Specify the file path and name
file_path = r"C:\Users\itssp\Desktop\NMIMS\SEMESTER IV\Machine Learning\Dataset\PreprocessedToyota.csv"

# Read the CSV file into a DataFrame, setting the index column
df = pd.read_csv(file_path, index_col=0)

# Display the DataFrame
print(df)

df=pd.read_csv(r"C:\Users\itssp\Desktop\NMIMS\SEMESTER IV\Machine Learning\Dataset\PreprocessedToyota.csv",index_col=0)
df
# Out:
#       Price        Age       KM FuelType     HP  MetColor  Automatic    CC  \
# 0     13500  23.000000  46986.0   Diesel   90.0       1.0          0  2000
# 1     13750  23.000000  72937.0   Diesel   90.0       1.0          0  2000
# 2     13950  24.000000  41711.0   Diesel   90.0       1.0          0  2000
# 3     14950  26.000000  48000.0   Diesel   90.0       0.0          0  2000
# 4     13750  30.000000  38500.0   Diesel   90.0       0.0          0  2000
# ...     ...        ...      ...      ...    ...       ...        ...   ...
# 1431   7500  55.672156  20544.0   Petrol   86.0       1.0          0  1300
# 1432  10845  72.000000  63634.0   Petrol   86.0       0.0          0  1300
# 1433   8500  55.672156  17016.0   Petrol   86.0       0.0          0  1300
# 1434   7250  70.000000  63634.0   Petrol   86.0       1.0          0  1300
# 1435   6950  76.000000      1.0   Petrol  110.0       0.0          0  1600
#
#       Doors  Weight
# 0         3    1165
# 1         3    1165
# ...

# %%
#checking the top 5 rows in data to understand the type of data
df.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000      3
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel  90.0       1.0          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
#checking if there are any null values in the data
df.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %%
#Getting the information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   float64
#  2   KM         1436 non-null   float64
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   float64
#  5   MetColor   1436 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 155.7+ KB

# %% [markdown]
# As our dataset has no missing values and it is clean, We can move further to implement pycaret library for predicting prices based on trained data

# %%
from pycaret.regression import *
s=setup(df,target='Price',session_id=123)
# Out:
# <style type="text/css">
# #T_a639a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a639a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a639a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a639a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a639a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a639a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a639a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a639a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a639a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a639a_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_a639a_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# Compare_models() compares all the regression models and selects the best model based on MSE,MAE,RMSE,R2, and Time taken to execute

# %%
model=compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           15:42:07
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_757a2 th {
#   text-align: left;
# }
# ...

# %%
model
# Out:
# Lasso(random_state=123)

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %% [markdown]
# We split the data into features and target for further implementation

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into features and target
features = df[['Weight', 'Doors', 'HP', 'MetColor', 'CC', 'FuelType', 'KM', 'Age', 'Automatic']]
target = df['Price']  # Extract 'Price' column from the DataFrame

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)
print("Training set size: ", len
      (y_train))  # The number
# of samples in the training set is
# approximately equal to 75% of all
# available samples
print("Testing set size: ", len(
    y_test), "\n")
# Out:
# Training set size:  1005
# Testing set size:  431

# %% [markdown]
# Predict_model is used to predict the price based on the model we pass and test data

# %%
predictions = predict_model(model, data=X_test)
predictions
# Out:
#       Weight  Doors     HP  MetColor    CC FuelType        KM        Age  \
# 594     1025      3   97.0       1.0  1400   Petrol   22500.0  50.000000
# 754     1055      3  110.0       1.0  1600   Petrol   80426.0  55.672157
# 630     1135      4   72.0       1.0  2000   Diesel  130000.0  59.000000
# 1259    1070      5  110.0       1.0  1600   Petrol   76000.0  71.000000
# 903     1075      5  110.0       0.0  1600   Petrol   59000.0  65.000000
# ...      ...    ...    ...       ...   ...      ...       ...        ...
# 560     1040      3  110.0       1.0  1600   Petrol   39291.0  54.000000
# 156     1105      4  110.0       1.0  1600   Petrol   13000.0  16.000000
# 618     1065      3  110.0       1.0  1600   Petrol  144000.0  64.000000
# 934     1015      3   86.0       1.0  1300   Petrol   55000.0  65.000000
# 916     1035      5   86.0       1.0  1300   Petrol   57565.0  68.000000
#
#       Automatic  prediction_label
# 594           0      11143.097243
# ...

# %%
# Renaming the column 'prediction_label' to 'Predicted_price'
predictions.rename(columns={'prediction_label': 'Predicted_price'}, inplace=True)

# %%
predictions
# Out:
#       Weight  Doors     HP  MetColor    CC FuelType        KM        Age  \
# 594     1025      3   97.0       1.0  1400   Petrol   22500.0  50.000000
# 754     1055      3  110.0       1.0  1600   Petrol   80426.0  55.672157
# 630     1135      4   72.0       1.0  2000   Diesel  130000.0  59.000000
# 1259    1070      5  110.0       1.0  1600   Petrol   76000.0  71.000000
# 903     1075      5  110.0       0.0  1600   Petrol   59000.0  65.000000
# ...      ...    ...    ...       ...   ...      ...       ...        ...
# 560     1040      3  110.0       1.0  1600   Petrol   39291.0  54.000000
# 156     1105      4  110.0       1.0  1600   Petrol   13000.0  16.000000
# 618     1065      3  110.0       1.0  1600   Petrol  144000.0  64.000000
# 934     1015      3   86.0       1.0  1300   Petrol   55000.0  65.000000
# 916     1035      5   86.0       1.0  1300   Petrol   57565.0  68.000000
#
#       Automatic  Predicted_price
# 594           0     11143.097243
# ...

# %% [markdown]
# We use evaluate_model to get the different plots and information about the model in visuals which include Pipeline plot, Residuals, Hyperparameters, Residuals, Prediction Error, Feature Selection, Learning Curve, Manifold Learning, Validation Curve, Feature Importance

# %%
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Empty DataFrame
# Columns: [col, contribution, value]
# Index: []
# Empty DataFrame
# Columns: [col, contribution, value]
# Index: []
# Empty DataFrame
# Columns: [col, contribution, value]
# Index: []
# Empty DataFrame
# Columns: [col, contribution, value]
# Index: []
# Empty DataFrame
# Columns: [col, contribution, value]
# Index: []
# Empty DataFrame
# Columns: [col, contribution, value]
# Index: []

# %% [markdown]
# We use dashboard() to get an interactive dashboard which will help us in understanding the predicted price, which will give the features importance, Regression stats, Individual Predictions, Feature dependence. It runs on the the IPv4 address of our system and a random port is assigned to it

# %%
dashboard(model)
# Out:
# WARNING: For shap='linear', shap interaction values can unfortunately not be calculated!
# ...
# Generating self.shap_explainer = shap.LinearExplainer(modelX)...
# Building ExplainerDashboard..
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# For this type of model and model_output interactions don't work, so setting shap_interaction=False...
# The explainer object has no decision_trees property. so setting decision_trees=False...
# Generating layout...
# Calculating shap values...
# Calculating predictions...
# Calculating residuals...
# Calculating absolute residuals...
# Calculating dependencies...
# Calculating importances...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...
# ...

# %% [markdown]
# Create_app() is used to create an application based on our model which will give us input fields of the dataset and based on the values we put, Price prediction is done!

# %%
create_app(model)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# IMPORTANT: You are using gradio version 4.31.0, however version 5.0.1 is available, please upgrade.
# --------
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
